# %%
import pickle
import numpy as np
import os
from collections import Counter

path = "~/data/verbosius/amazon/chunking/amazon_chunkdist_1250/train"
path = os.path.expanduser(path)

listdir = os.listdir(path)

for i in range(20):

    chunk = np.random.choice(listdir)
    chunk = pickle.load(open(os.path.join(path, chunk), "rb"))

    print(Counter(chunk["train_y"]))
# Out:
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})
# Counter({0: 2666, 1: 2666, 2: 2666})

# %%
import pickle
import numpy as np
import os
from collections import Counter

data = "huge"

path = f"~/data/verbosius/amazon/pre_chunking/{data}/test_data.pkl"
path = os.path.expanduser(path)
testdata = pickle.load(open(path, "rb"))
print(Counter(testdata[:,1]))

path = f"~/data/verbosius/amazon/pre_chunking/{data}/train_data.pkl"
path = os.path.expanduser(path)  
traindata = pickle.load(open(path, "rb"))
print(Counter(traindata[:,1]))
# Out:
# Counter({4: 200000, 0: 200000, 3: 200000, 1: 200000, 2: 200000})
# Counter({1: 5000000, 0: 5000000, 2: 5000000})

# %%
string = "file_e.pkl"

string[-5]
# Out:
# 'e'

# %%
import os

root = "/home/verbosius/data/"
file = "train.pkl"

path = os.path.join(root, file)

print(path)
# Out:
# /home/verbosius/data/train.pkl

# %%
import os
import pickle
import gzip

path = "/home/bigtech/data/verbosius/amazon/preprocess/amazon_chunkdist_1250/init_chunk_0_.pkl"

# check space
b = os.path.getsize(path)
b = b / (1024**3)
print(b, "GB")

with open(path, "rb") as f:
    data = pickle.load(f)

with gzip.open("/home/bigtech/test.pkl", "wb") as f:
    data = pickle.dump(data, f)

b = os.path.getsize("/home/bigtech/test.pkl")
b = b / (1024**3)
print(b, "GB")
# Out:
# 0.012659568339586258 GB
# 0.0033441316336393356 GB

# %%
import os
import gzip
from tqdm import tqdm
import pickle

path = "/home/bigtech/data/verbosius/amazon/trainingdata/amazon_chunkdist_1250"

files = os.listdir(path)

print(len(files))
# Out:
# 2500

# %%
import config as config

config.dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 import config as config
# ----> 3 config.dataset
#
# AttributeError: module 'config' has no attribute 'dataset'
