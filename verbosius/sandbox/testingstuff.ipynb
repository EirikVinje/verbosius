# %%
import numpy as np

# %%
a = np.array([[1, 2, 3], [1, 2, 3], [1, 2, 3], [1, 2, 3]])


a[:, 1:3]
# Out:
# array([[2, 3],
#        [2, 3],
#        [2, 3],
#        [2, 3]])

# %%
a = [1, 2, 3, 4, 5]

# index lookup at value 2
a.index(2)
# Out:
# 1
