# %%
# get whole path
import os
print(os.path.abspath(""))

# get root path
print(os.path.abspath("b"))
# Out:
# /home/kolla/projects/verbosius/verbosius/sandbox
# /home/kolla/projects/verbosius/verbosius/sandbox/home

# %%
# import rottentomatoes from tra

import datasets

# load rotten
rt = datasets.load_dataset("rottentomatoes")

# %%
from typing import Any


class Test:

    def __init__(self):
        print("init")

    def _say_hello(self):
        print("hello")
# Out:
# init

# %%
import time

# get date, time, seconds
localtime = f"{time.localtime().tm_year}{time.localtime().tm_mon}{time.localtime().tm_mday}_{time.localtime().tm_hour}{time.localtime().tm_min}"
print(localtime)
# Out:
# 202373_455

# %%
from collections import Counter

s = "sweet"

if Counter(s)[" "] == 1:
    print("ok")


toks = ["hello", "my", "name is", "eirik"]
toks.pop(1)
toks.pop(1)
toks.insert(1, "the")
toks
# Out:
# ['hello', 'the', 'eirik']

# %%
s = "this is a sentence"
s_split = s.split()
s_last = s_split[-1]

s.find(s_last, len(s) - len(s_last))
# Out:
# 10

# %%
import re

# make regex for tuples : (0,1)
regex = re.compile(r"\((\d+),(\d+)\)")

s = "(0,1)"

# match regex
match = regex.match(s)

if match is None:
    print("no match")

# %%
import os

os.path.expanduser("~/projects")
# Out:
# '/home/kolla/projects'

# %%
import os
path = "/home/kolla/projects/verbosius/sandbox"

# get parent dir to path
parent_dir = os.path.dirname(path)
print(parent_dir)
# Out:
# /home/kolla/projects/verbosius

# %%
a = [1, 2, 3]

b = []

a.extend(b) if b != None else None

print(a)
# Out:
# [1, 2, 3]

# %%
from sklearn.model_selection import train_test_split

data = [i for i in range(10)]

train_data, eval_data = train_test_split(data, test_size=0.2, random_state=42)

print(train_data)
print(eval_data)
# Out:
# [5, 0, 7, 2, 9, 4, 3, 6]
# [8, 1]

# %%
l = ['train_val_chunk_2.pkl', 'train_val_chunk_1.pkl', 'train_val_chunk_0.pkl', 'train_val_chunk_3_e.pkl']

print(l)
print(sorted(l))
# Out:
# ['train_val_chunk_2.pkl', 'train_val_chunk_1.pkl', 'train_val_chunk_0.pkl', 'train_val_chunk_3_e.pkl']
# ['train_val_chunk_0.pkl', 'train_val_chunk_1.pkl', 'train_val_chunk_2.pkl', 'train_val_chunk_3_e.pkl']

# %%
import datetime

str(datetime.datetime.now())
# Out:
# '2023-09-04 14:25:11.301276'

# %%
a = ["hello", "world"]

b = {"a" : [1, 3, 4], "b" : [2, 3, 4]}
# Out:
# ['hello', 'world', {'a': [1, 3, 4], 'b': [2, 3, 4]}]

# %%
import numpy as np

a = [[1, 2, 3], [4, 5, 6], [7, 8, 9], [1, 2, 3]]

a = np.array(a)

print(a.shape)

a[:, 1]
# Out:
# (4, 3)
# array([2, 5, 8, 2])

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilroberta-base")

tokenizer.convert_ids_to_tokens(range(10))
# Out:
# ['<s>', '<pad>', '</s>', '<unk>', '.', 'Ġthe', ',', 'Ġto', 'Ġand', 'Ġof']

# %%
import os
import subprocess

#config = os.system("cat /home/bigtech/projects/verbosius/verbosius/config.py")
config = subprocess.check_output(["cat", "/home/bigtech/projects/verbosius/verbosius/config.py"])

config = str(config)

print(config[0:3])
# Out:
# b'f
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/bigtech/projects/verbosius/verbosius/sandbox/testing_paths.ipynb Cell 17 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bneuromancer/home/bigtech/projects/verbosius/verbosius/sandbox/testing_paths.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> config = str(config)
#       <a href='vscode-notebook-cell://ssh-remote%2Bneuromancer/home/bigtech/projects/verbosius/verbosius/sandbox/testing_paths.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> print(config[0:3])
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bneuromancer/home/bigtech/projects/verbosius/verbosius/sandbox/testing_paths.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> assert False
# ...

# %%
print(config)
# Out:
# 0
